# %%
import os
import glob

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in train.txt into df
labels = pd.read_csv("C:\\Users\\limxu\\Documents\\Intern\data\\train.txt", names = ["speed"])
print(labels.head())
# Out:
#        speed
# 0  28.105569
# 1  28.105569
# 2  28.106527
# 3  28.130404
# 4  28.109243

# %%
labels.plot(kind="line", y='speed')
